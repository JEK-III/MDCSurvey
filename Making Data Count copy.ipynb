# %% [markdown]
# # Making Data Count

# %% [markdown]
# This notebook is for styling figures to suit print publication

# %% [markdown]
# ## Introduction

# %% [markdown]
# In November and December of 2014, we conducted a pair of online surveys of researchers and data managers (i.e., database or repository staff), asking questions about data sharing, discovery, and metrics

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
from IPython.display import display
from math import sqrt
from textwrap import wrap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab
import scipy as sp
import scipy.stats as sps
import seaborn as sns

#pylab.rcParams['figure.figsize'] = (14.0, 6.0)
pylab.rcParams['savefig.bbox'] = 'tight'
sns.set_style("white", 
              {'font.sans-serif': ['Helevetica', 'Liberation Sans', 
                                   'Bitstream Vera Sans', 'sans-serif'],
               'axes.linewidth': 0,
               'xtick.direction': 'in',
               'xtick.major.size': 8.0})

LABEL_WIDTH = 25
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.15',
#  'axes.facecolor': 'white',
#  'axes.grid': False,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 0,
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Helevetica',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'image.cmap': 'Greys',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': 'in',
#  'xtick.major.size': 8.0,
#  'xtick.minor.size': 0,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.major.size': 0,
#  'ytick.minor.size': 0}

# %% [markdown]
# Scheme to consolidate subdisciplines

# %%
DISCIPLINE_MAP = {'-Anthropology' : 'Social science',
                  '-Archaeology' : 'Archaeology',
                  '-Area studies' : 'Social science',
                  '-Economics' : 'Social science',
                  '-Political science' : 'Social science',
                  '-Psychology' : 'Social science',
                  '-Sociology' : 'Social science',
                  '-Astronomy' : 'Space science',
                  '-Astrophysics' : 'Space science',
                  '-Environmental Science' : 'Environmental science',
                  '-Geology' : 'Earth science',
                  '-Oceanography' : 'Environmental science',
                  '-Planetary science' : 'Earth science',
                  '-Biochemistry' : 'Biology',
                  '-Bioinformatics' : 'Biology',
                  '-Biology' : 'Biology',
                  '-Evolutionary Biology' : 'Biology',
                  '-Neurobiology' : 'Biology',
                  'Social science' : 'Social science',
                  'Space science' : 'Space science',
                  'Earth science' : 'Earth science',
                  'Life science' : 'Biology',
                  'Chemistry' : 'Physical science',
                  'Physics' : 'Physical science',
                  'Computer science' : 'Computer science',
                  'Mathematics' : 'Mathematics',
                  'Information science' : 'Information science',
                  'Other' : 'Other'}

# %% [markdown]
# Misc. utilities

# %%
def tuple_normalize(counts, n_responses):
    return map(lambda x: float(x) / n_responses * 100, counts)

def interval_to_error(confidence_interval, center):
    """
    confidence_interval (tuple): low, high relative to the origin
    center: (int, float): measured value (e.g., mean)
    returns the ci as a tuple relative to the center (i.e., minus, plus the mean)
    """
    return tuple(map(lambda x: abs(float(x) - center), confidence_interval))
    
def split_interval(interval):
    """
    split a confidence interval tuple and return as a 2-element Series
    """
    return pd.Series(interval, index= ['low','high'])

# %% [markdown]
# #### Bootstrap functions

# %%
def bootstrap_percentile_ci(data, n_samples=100000, alpha=0.05, stat_function=np.sum):
    """
    Calculates a confidence interval for True/False count data and returns a tuple (low, high) 
    
    data: (numpy array) of bools to resample
    num_samples: (int) number of times to resample
    alpha: (float) 1 - desired confidence interval  
    """
    n_responses = len(data)
    # get num_samples resampled arrays (of length n) of valid indicies for data
    indicies = np.random.randint(0, n_responses, (n_samples, n_responses))
    
    # generate sorted array of desired stat in each resampled array
    stats = [stat_function(data[x]) for x in indicies]
    stats.sort()

    # return stats at the edge of the 2.5 and 97.5 percentiles
    return (stats[int((alpha/2.0)*n_samples)], stats[int((1-alpha/2.0)*n_samples)])


def bootstrap_basic_ci(data, n_samples=100000, alpha=0.05, stat_function=np.sum):
    """
    Calculates a confidence interval for True/False count data and returns a tuple (low, high) 
    
    data: (numpy array) of bools to resample
    num_samples: (int) number of times to resample
    alpha: (float) 1 - desired confidence interval  
    """
    double_observed = 2 * stat_function(data)
    high, low = bootstrap_percentile_ci(data, n_samples=n_samples, alpha=alpha, stat_function=stat_function)

    return (double_observed - low, double_observed - high)

# %% [markdown]
# #### Graphing functions

# %%
def apply_cdl_style(fig):
    fig.set_ylabel('')
    sns.despine(ax=fig, left=True)
    # get rid of weird dashed line
    fig.lines[0].set_visible(False) 
    
    #set font sizes
    fig.tick_params(axis='x', width=2, labelsize=18, color='#808080')
    fig.tick_params(axis='y', labelsize=24)
    
    return fig

# %%
def graph_likert(questions, answers, interval_color='#808080'):
    
    collected_counts = pd.DataFrame(index=answers)
    stats = pd.DataFrame(index=questions.columns,columns=['mean', 'ci'])

    # set up dict for converstion from likert scale (e.g., 1-5) to 0-100%
    number_of_answers = len(answers) 
    answer_to_value = dict(zip(answers, np.arange(number_of_answers)/float(number_of_answers - 1)*100)) 

    for column in questions.columns:
        collected_counts[column] = questions[column].value_counts().dropna()

        #scale responses to go from 0 to 100
        likert_values = questions[column].dropna().map(answer_to_value)

        #cacluate mean and 95% confidence interval
        stats['mean'].loc[column] = likert_values.mean() 
        stats['ci'].loc[column] = bootstrap_basic_ci(np.array(likert_values), stat_function=np.mean)
        
    #sort stats and collected_counts by the mean   
    stats = stats.sort_index(axis=0, by='mean', ascending=True)
    collected_counts = collected_counts.T.reindex(index=stats.index)
    collected_counts = collected_counts.div(collected_counts.sum(1).astype(float)/100, axis = 0)
    
    #convert absolute interval values to distance below and above the observed value
    for index in stats.index.values:
        stats['ci'].loc[index] = interval_to_error(stats['ci'].loc[index], stats['mean'].loc[index])
    
    #split interval tuples into 2 element Series
    stats['ci'] = stats['ci'].apply(split_interval)
    
    collected_counts.index = [ '\n'.join(wrap(i, LABEL_WIDTH)) for i in collected_counts.index ]
    
    #plot percentages of each response
    fig = collected_counts.plot(kind='barh', stacked=True, grid=False, 
                                color=sns.color_palette("Blues", len(collected_counts.columns)),
                                width=0.75, xlim = (0,100), edgecolor='w', linewidth=2) 
    
    # plot mean and 95% confidence interval
    fig.plot(stats['mean'], np.arange(len(stats)), marker='o', color='w',axes=fig, 
             markersize=25, markeredgewidth=0, linewidth=0)
    
    fig.errorbar(stats['mean'].as_matrix()[::-1], np.arange(len(stats))[::-1], xerr=stats['ci'],
                 fmt='none', ecolor=interval_color, alpha=0.65, elinewidth=2, capsize=12, capthick=2)
    
    fig.legend(bbox_to_anchor=(0., -0.02, 1., -0.03), loc='upper left', ncol=number_of_answers, mode="expand",
                    borderaxespad=0., fontsize=20)
    
    apply_cdl_style(fig)
    
    fig.get_figure().set_size_inches(14.0, 2 * len(collected_counts.index))

    return fig , collected_counts

# %%
def graph_checkbox(question, bar_color='#08519c', interval_color='#808080'):
    #split_checkbox = responses[question].dropna()

    # checkbox_responses== DataFrame of bools where index=individual respondents, columns=answer choices
    #checkbox_responses = expand_checkbox(split_checkbox, answers)
    checkbox_responses = question.applymap(pd.notnull)
    
    # sum checked boxes in each column; response_counts== Series with values=sums, index=answer choices
    response_counts = checkbox_responses.sum()
    
    # resample and sum from each column to bootstrap a confidence interval
    # count_confidence_intervals== Series with values= tuples (low, high), index=answer choices
    count_confidence_intervals = checkbox_responses.apply(lambda x: bootstrap_basic_ci(np.array(x)))
        
    #normalize response_counts to percentage of total respondents to the question and sort
    response_counts = response_counts.apply(lambda x: float(x) / len(checkbox_responses) * 100)
    response_counts.sort(ascending=True)
    
    
    #normalize confidence intervals to percentages
    count_confidence_intervals = count_confidence_intervals.apply(tuple_normalize, args=([len(checkbox_responses)]))
    
    
    #convert absolute interval values to distance below and above the observed value
    for index in count_confidence_intervals.index.values:
        count_confidence_intervals.loc[index] = interval_to_error(count_confidence_intervals.loc[index], 
                                                                  response_counts.loc[index])
    
    #split interval tuples into 2 element Series
    count_confidence_intervals = count_confidence_intervals.apply(split_interval)
    
    response_counts.index = [ '\n'.join(wrap(i, LABEL_WIDTH)) for i in response_counts.index ]

    
    fig = response_counts.plot(kind='barh', 
                               color='#08519c',
                               edgecolor='w', grid=False, xlim=(0,100), fontsize=14)
    fig.errorbar(response_counts.as_matrix()[::-1], np.arange(len(response_counts))[::-1], 
                 xerr=count_confidence_intervals.T.as_matrix(),
                 fmt='none', ecolor=interval_color, alpha=0.65, elinewidth=2, capsize=12, capthick=2)
    
    
    apply_cdl_style(fig)

    fig.get_figure().set_size_inches(14.0, 2 * len(response_counts.index))
    
    return fig, response_counts, count_confidence_intervals

# %% [markdown]
# # Researchers

# %%
responses = pd.read_csv('MDC_Researchers - MDC_Researchers.tsv', 
                        sep='\t',
                        header=[0,1], 
                        index_col=0,
                        tupleize_cols=True)

# drop blank rows (ignoring 1st column, which is required)
responses.dropna(axis=0, how='all', subset=responses.columns[1:], inplace=True)

responses.columns = pd.MultiIndex.from_tuples(responses.columns, names=['question', 'subquestion'])
responses.sort_index(axis=1, inplace=True)

responses['Which best describes your discipline?', 'Response'] = (
    responses['Which best describes your discipline?', 'Response'].map(DISCIPLINE_MAP, na_action='Ignore'))

# %% [markdown]
# ### Demographics

# %%
DEMOGRAPHICS = ['Which best describes your employer/institution?', 
                'Where is your employer/institution located?', 
                'What is the highest degree you hold?', 
                'Which best describes your role?', 
                'Which best describes your discipline?']

print("N= " + str(len(responses.index)))

for column in DEMOGRAPHICS:
    count = responses[column, 'Response'].value_counts()
    percentages = 100 * count.apply(lambda x: float(x) / count.sum())
    display(pd.DataFrame([count, percentages], index=['count', 'percent']).T)
# Out:
# N= 247
#                         count    percent
# Academic                  173  78.280543
# Government                 20   9.049774
# Nonprofit                  13   5.882353
# Commerical                 10   4.524887
# Other (please specify)      5   2.262443
#                 count    percent
# United States     124  57.142857
# United Kingdom     31  14.285714
# Canada              8   3.686636
# Portugal            7   3.225806
# Germany             7   3.225806
# Australia           5   2.304147
# Netherlands         3   1.382488
# France              3   1.382488
# Sweden              3   1.382488
# Spain               3   1.382488
# Norway              2   0.921659
# Puerto Rico         2   0.921659
# Belgium             2   0.921659
# Finland             2   0.921659
# India               2   0.921659
# Brazil              1   0.460829
# Italy               1   0.460829
# Israel              1   0.460829
# Denmark             1   0.460829
# Iran                1   0.460829
# Mexico              1   0.460829
# Ireland             1   0.460829
# Switzerland         1   0.460829
# New Zealand         1   0.460829
# Hungary             1   0.460829
# Pakistan            1   0.460829
# Saudi Arabia        1   0.460829
# Argentina           1   0.460829
#            count    percent
# Doctorate    162  73.303167
# Masters       42  19.004525
# Bachelors     17   7.692308
#                         count    percent
# PI / Lab Head              93  42.081448
# Postdoc                    47  21.266968
# Graduate student           41  18.552036
# Other (please specify)     26  11.764706
# Technician / Staff         14   6.334842
#                        count    percent
# Biology                  114  53.023256
# Environmental science     37  17.209302
# Social science            21   9.767442
# Computer science          14   6.511628
# Information science        9   4.186047
# Earth science              8   3.720930
# Physical science           8   3.720930
# Space science              3   1.395349
# Mathematics                1   0.465116

# %% [markdown]
# A total of 247 respondents completed the researcher survey. Most (78%) are employed by academic institutions. The United States (57%) and United Kingdom (14%) are easily the best represented countries. We received responses from across the academic career spectrum: principle investigators, post-docs, and grad students are all well represented. Biology is the most popular domain (53%), but environmental (17%) and social (10%) science are also significantly represented.

# %% [markdown]
# ## Discovery

# %% [markdown]
# ### How frequently do you use data from public sources to accomplish each of the following?

# %%
FREQUENCIES = ['Never', 'Occasionally', 'Often']
sources_graph, sources_table = graph_likert(responses['How frequently do you use data from public sources to accomplish each of the following?<br>(e.g., data in a public database or journal article supplemental material)'], 
                               FREQUENCIES)
plt.savefig('mdc_use.svg')

# %% [markdown]
# Survey respondents most frequently reused public data as support for their own data collection– either before (to inform data collection) or after (to support interpretation). However, the number who did "often" reuse data to reach the main conclusions (27.8%) is still quite signficant.

# %%
reuse_data = responses['How frequently do you use data from public sources to accomplish each of the following?<br>(e.g., data in a public database or journal article supplemental material)']
never_reuse_count = reuse_data.apply(lambda x: x == 'Never').all(axis=1).value_counts()
never_reuse_percent = never_reuse_count.apply(lambda x: 100 * float(x) / never_reuse_count.sum())
print(str(never_reuse_count[True]) + " (" + str(never_reuse_percent[True]) + 
      "%) respondents answered 'Never' to all options.")

often_reuse_count = reuse_data.apply(lambda x: x == 'Often').any(axis=1).value_counts()
often_reuse_percent = often_reuse_count.apply(lambda x: 100 * float(x) / often_reuse_count.sum())
print(str(often_reuse_count[True]) + " (" + str(often_reuse_percent[True]) + 
      "%) respondents answered 'Often' to at least one option.")
# Out:
# 9 (3.64372469636%) respondents answered 'Never' to all options.
# 139 (56.2753036437%) respondents answered 'Often' to at least one option.

# %% [markdown]
# ### When looking for public data to use, how likely you are to search in each of the following ways?

# %%
LIKELIHOODS = ['No chance', 'Possible', 'Definitely']
graph_likert(responses['When looking for public data to use, how likely you are to search in each of the following ways?<br><em>If you never use external data, please answer hypothetically.</em>'], 
             LIKELIHOODS) 
plt.savefig('mdc_discovery.svg')

# %% [markdown]
# Most respondents search for data in multiple ways: through links from the literature, disciplinary databases, and general-purpose internet search. More personal reliance on other researchers (via social media or discussion forums) is much less common.

# %%
search_method = responses['When looking for public data to use, how likely you are to search in each of the following ways?<br><em>If you never use external data, please answer hypothetically.</em>']
definite_methods = search_method.apply(lambda x : x == 'Definitely').sum(axis=1).value_counts().sort_index()
definite_methods = definite_methods.apply(lambda x: float(x) / definite_methods.sum() * 100)
dm_fig = definite_methods.plot(kind='bar', color='#08519c', edgecolor='w', grid=False, ylim=(0,100), fontsize=16, rot=0,
                               title='How many methods would you "definitely" use?')
sns.despine(ax=dm_fig)
print(str(definite_methods[2:].sum()) + '% "definitely" use 2 or more methods')
# Out:
# 62.7530364372% "definitely" use 2 or more methods

# %% [markdown]
# A majority (63%) of respondents use multiple methods to search for data.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Please rank the importance of the following for estimating a dataset's quality

# %%
IMPORTANCE_LEVELS = ['5 (Least important)', '4', '3', '2', '1 (Most important)']
graph_likert(responses["Please rank the importance of the following for estimating a dataset's quality (e.g., when deciding whether to download it).<br><em>Please rank items from most to least important.</em>"], 
             IMPORTANCE_LEVELS)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10920d9d0>,
#                                            5 (Least important)          4  \
#  Amount of reuse by others                           47.807018  19.298246
#  Reputation of the\ncreator(s)                       15.596330  29.816514
#  Reputation of the\ndatabase / repository            12.195122  18.048780
#  Quality of associated\npublication(s)                7.960199  21.393035
#  Thoroughness of the\ndocumentation                   4.975124  10.945274
#
#                                                    3          2  \
#  Amount of reuse by others                 16.228070   9.210526
#  Reputation of the\ncreator(s)             22.935780  20.642202
#  Reputation of the\ndatabase / repository  28.292683  25.853659
#  Quality of associated\npublication(s)     23.383085  31.840796
#  Thoroughness of the\ndocumentation        12.935323  19.402985
#
#                                            1 (Most important)
#  Amount of reuse by others                           7.456140
#  Reputation of the\ncreator(s)                      11.009174
#  Reputation of the\ndatabase / repository           15.609756
#  Quality of associated\npublication(s)              15.422886
#  Thoroughness of the\ndocumentation                 51.741294  )

# %% [markdown]
# Data quality was most frequently estimated through thoroughness of the associated documentation. Somewhat surprisingly, reuse was the least important indicator.

# %% [markdown]
# ## Data Use

# %% [markdown]
# ### What proportion of your data have you shared in each of the following ways?

# %%
PROPORTIONS = ['None', 'Some of it', 'Most/all of it']

"""
Responses to "Any means at all" generally make no sense (e.g., 44 of the 48 respondents who said they shared none of their 
data by any means also said that they shared some or most of their data through one of the other means. 
Consequently, I am dropping that question from the analysis."
"""

sharing_method = responses['What proportion of your data have you shared in each of the following ways?'].copy()
sharing_method.drop('Any means at all', axis=1, inplace=True)

graph_likert(sharing_method, PROPORTIONS)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x115be1e90>,
#                                                    None  Some of it  \
#  Personal or lab website                      45.871560   44.495413
#  Journal website (as\nsupplemental material)  31.651376   56.422018
#  Database or repository                       28.571429   47.465438
#  Email / direct contact                       10.045662   74.429224
#
#                                               Most/all of it
#  Personal or lab website                            9.633028
#  Journal website (as\nsupplemental material)       11.926606
#  Database or repository                            23.963134
#  Email / direct contact                            15.525114  )

# %% [markdown]
# More respondents (90%) have shared data by email than any other method. However, respondents who shared most or all of their data were more likely to do so via a database or repository (24%).

# %%
#sharing_method = responses['What proportion of your data have you shared in each of the following ways?']
shared_all_data = sharing_method.apply(lambda x : x == 'Most/all of it').any(axis=1)
fig, table = graph_likert(sharing_method[shared_all_data], PROPORTIONS)

print(str(shared_all_data.sum()) + ' (' + (str(100. * shared_all_data.sum()/shared_all_data.size)) + 
      '%) shared "most/all" of their data by some means')
# Out:
# 94 (38.0566801619%) shared "most/all" of their data by some means

# %%
table
# Out:
#                                                   None  Some of it  \
# Personal or lab website                      32.967033   43.956044
# Journal website (as\nsupplemental material)  23.076923   48.351648
# Email / direct contact                        7.608696   55.434783
# Database or repository                        9.890110   32.967033
#
#                                              Most/all of it
# Personal or lab website                           23.076923
# Journal website (as\nsupplemental material)       28.571429
# Email / direct contact                            36.956522
# Database or repository                            57.142857

# %%
shared_no_data = sharing_method.apply(lambda x : x == 'None').all(axis=1)
shared_no_data.sum() / 247.
#sharing_method[sharing_method['Any means at all'] == 'None']
# Out:
# 0.016194331983805668

# %% [markdown]
# ### How interested you would be to know each of the following about users of your data?

# %%
INTEREST_LEVELS = ['5 (Least interesting)', '4', '3', '2', '1 (Most interesting)']
graph_likert(responses['How interested you would be to know each of the following about <strong>users<br></strong> of your data?<br><em>Please rank items from most to least interesting.</em>'], 
             INTEREST_LEVELS)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10963c310>,
#                                                                5 (Least interesting)  \
#  Geographic locations                                                      57.990868
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)              10.232558
#  Institutional\naffiliations                                               10.952381
#  Names & contact\ninformation                                              13.488372
#  Disciplines / research\ncommunities                                        5.555556
#
#                                                                        4  \
#  Geographic locations                                          15.525114
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)  42.325581
#  Institutional\naffiliations                                   20.000000
#  Names & contact\ninformation                                  11.627907
#  Disciplines / research\ncommunities                           10.648148
#
#                                                                        3  \
#  Geographic locations                                          15.525114
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)  20.000000
#  Institutional\naffiliations                                   42.380952
#  Names & contact\ninformation                                   9.767442
#  Disciplines / research\ncommunities                           14.351852
#
#                                                                        2  \
#  Geographic locations                                           5.936073
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)  19.534884
#  Institutional\naffiliations                                   20.952381
#  Names & contact\ninformation                                  16.744186
#  Disciplines / research\ncommunities                           37.500000
#
#                                                                1 (Most interesting)
#  Geographic locations                                                      5.022831
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)              7.906977
#  Institutional\naffiliations                                               5.714286
#  Names & contact\ninformation                                             48.372093
#  Disciplines / research\ncommunities                                      31.944444  )

# %% [markdown]
# ### How interested you would be to know each of the following about how your data is used?

# %%
graph_likert(responses['How interested you would be to know each of the following about <strong>how<br></strong> your data is used?<br><em>Please rank items from most to least interesting.</em>'], 
             INTEREST_LEVELS)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10a3b7310>,
#                                     5 (Least interesting)          4  \
#  If a subset was used                           34.905660  36.320755
#  If combined with other\ndata                   18.224299  26.168224
#  If a dataset was derived\nfrom it              10.798122  19.718310
#  If data was misused                            28.899083   7.798165
#  If analyses were\nperformed                     6.511628   9.302326
#
#                                             3          2  1 (Most interesting)
#  If a subset was used               20.283019   7.075472              1.415094
#  If combined with other\ndata       25.233645  14.485981             15.887850
#  If a dataset was derived\nfrom it  36.150235  23.474178              9.859155
#  If data was misused                 8.715596  18.807339             35.779817
#  If analyses were\nperformed        10.232558  36.744186             37.209302  )

# %% [markdown]
# ## Impact

# %% [markdown]
# ### How interested you would be to know each of the following about the impact of your data?

# %%
INTEREST_LEVELS_FOUR = ['4 (Least interesting)', '3', '2', '1 (Most interesting)']
graph_likert(responses['How interested you would be to know each of the following about the impact of your data?<br><em>Please rank items from most to least interesting.</em>'], 
             INTEREST_LEVELS_FOUR)
plt.savefig('mdc_impact.svg')

# %% [markdown]
# Citations remain the preferred currency of academic credit, as the first choice of 85.5% of respondents. Download count is a clear second choice (by 64.5%). Links and landing page views were both much less popular.

# %% [markdown]
# # Data managers

# %%
responses = pd.read_csv('MDC_Managers - MDC_Managers.tsv', 
                        sep='\t',
                        header=[0,1], 
                        index_col=0,
                        tupleize_cols=True)

# drop blank rows (ignoring 1st column, which is required)
responses.dropna(axis=0, how='all', subset=responses.columns[1:], inplace=True)

responses.columns = pd.MultiIndex.from_tuples(responses.columns, names=['question', 'subquestion'])
responses.sort_index(axis=1, inplace=True)

responses['Which best describes your discipline?', 'Response'] = (
    responses['Which best describes your discipline?', 'Response'].map(DISCIPLINE_MAP, na_action='Ignore'))

# %% [markdown]
# ## Demographics

# %%
DEMOGRAPHICS = ['Which best describes your employer/institution?', 
                'Where is your employer/institution located?', 
                'What is the highest degree you hold?', 
                'Which best describes your discipline?']

print("N= " + str(len(responses.index)))

for column in DEMOGRAPHICS:
    count = responses[column, 'Response'].value_counts()
    percentages = 100 * count.apply(lambda x: float(x) / count.sum())
    display(pd.DataFrame([count, percentages], index=['count', 'percent']).T)
# Out:
# N= 73
#             count    percent
# Academic       35  63.636364
# Government     12  21.818182
# Nonprofit       7  12.727273
# Commerical      1   1.818182
#                 count    percent
# United States      39  72.222222
# United Kingdom      6  11.111111
# Germany             4   7.407407
# Portugal            1   1.851852
# New Zealand         1   1.851852
# Ireland             1   1.851852
# Australia           1   1.851852
# Canada              1   1.851852
#            count    percent
# Masters       35  66.037736
# Doctorate     14  26.415094
# Bachelors      4   7.547170
#                        count    percent
# Information science       21  41.176471
# Environmental science     12  23.529412
# Biology                    6  11.764706
# Computer science           6  11.764706
# Earth science              2   3.921569
# Space science              2   3.921569
# Archaeology                1   1.960784
# Social science             1   1.960784

# %% [markdown]
# ## Current Practice

# %% [markdown]
# ### What metrics / statistics do you currently track?

# %%
graph_checkbox(responses['What metrics / statistics do you currently track?'])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10a3a7490>,
#  Other (please specify)                      16.438356
#  Citations to your\nrepository as a whole    21.917808
#  Citations to individual\ndatasets           23.287671
#  Views                                       65.753425
#  Downloads                                   84.931507
#  dtype: float64,
#                                                 low       high
#  subquestion
#  Citations to individual datasets          9.589041   9.589041
#  Citations to your repository as a whole   9.589041   9.589041
#  Downloads                                 8.219178   8.219178
#  Other (please specify)                    9.589041   8.219178
#  Views                                    10.958904  10.958904)

# %%
tracked_metrics = responses['What metrics / statistics do you currently track?'].copy()
tracked_metrics.drop('Other (please specify)', axis=1, inplace=True)
tracked_fig, tracked_table, tracked_interval = graph_checkbox(tracked_metrics)

# %%
tracked_table
# Out:
# Citations to your\nrepository as a whole    21.917808
# Citations to individual\ndatasets           23.287671
# Views                                       65.753425
# Downloads                                   84.931507
# dtype: float64

# %% [markdown]
# A significant majority (84.9%) of repositories track downloads. Relatively few (23.3%) track citations to datasets or the repository as a whole (21.9%).

# %% [markdown]
# ### What metrics / statistics do you currently expose? (e.g., on landing pages or via API)

# %%
graph_checkbox(responses['What metrics / statistics do you currently expose?<br>(e.g., on landing pages or via API)'])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x109637210>,
#  Citations to your\nrepository as a whole     6.849315
#  Citations to individual\ndatasets           10.958904
#  Other (please specify)                      23.287671
#  Views                                       27.397260
#  Downloads                                   30.136986
#  dtype: float64,
#                                                 low      high
#  subquestion
#  Citations to individual datasets          8.219178  6.849315
#  Citations to your repository as a whole   6.849315  5.479452
#  Downloads                                10.958904  9.589041
#  Other (please specify)                    9.589041  9.589041
#  Views                                    10.958904  9.589041)

# %%
exposed_metrics = responses['What metrics / statistics do you currently expose?<br>(e.g., on landing pages or via API)'].copy()
exposed_metrics.drop('Other (please specify)', axis=1, inplace=True)
exposed_fig, exposed_table, exposed_interval = graph_checkbox(exposed_metrics, bar_color='#6baed6')

# %% [markdown]
# Most repositories do not expose any metrics/statistics. Of those that do, downloads (30.1%) and views (23.3%) are the most common. All metrics are collected by a significant number of repositories that do not expose them; 64.5% of the repositories that track downloads don't expose them; 52.9% of the repositories that track citations to individual datasets don't expose them.

# %%
exposed_table
# Out:
# Citations to your\nrepository as a whole     6.849315
# Citations to individual\ndatasets           10.958904
# Views                                       27.397260
# Downloads                                   30.136986
# dtype: float64

# %%
combined_metrics = {'tracked' : tracked_table,
                    'exposed' : exposed_table}
combined_df = pd.DataFrame(combined_metrics)
fig= combined_df.plot(kind='barh', color=sns.color_palette("Blues", 2), edgecolor='w',
                      grid=False, width=0.75, xlim=(0,100), fontsize=14)
fig.legend(loc=4,frameon=False, fontsize=20)

fig.get_figure().set_size_inches(14.0, 2 * len(tracked_table.index))

fig.errorbar(tracked_table.as_matrix()[::-1], np.arange(len(tracked_interval))[::-1] + 0.125, 
             xerr=tracked_interval.T.as_matrix(),
             fmt='none', ecolor='#808080', alpha=0.65, elinewidth=2, capsize=6, capthick=2)

fig.errorbar(exposed_table.as_matrix()[::-1], np.arange(len(exposed_interval))[::-1] - 0.125, 
             xerr=exposed_interval.T.as_matrix(),
             fmt='none', ecolor='#808080', alpha=0.65, elinewidth=2, capsize=6, capthick=2)
apply_cdl_style(fig)

plt.savefig('mdc_practice.svg')

# %% [markdown]
# ### What information do you require data users to supply?

# %%
graph_checkbox(responses['What information do you require data users to supply?'])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10a8c7950>,
#  Other (please specify)    13.698630
#  Other personal details    15.068493
#  Institution               39.726027
#  Email address             43.835616
#  None                      46.575342
#  Real name                 46.575342
#  dtype: float64,
#                                low       high
#  subquestion
#  Email address           10.958904  10.958904
#  Institution             10.958904  10.958904
#  None                    10.958904  10.958904
#  Other (please specify)   8.219178   6.849315
#  Other personal details   8.219178   8.219178
#  Real name               10.958904  10.958904)

# %% [markdown]
# Responding repositories were evenly split (at 46.6%) between requiring data users to supply their real name and requiring no information at all.

# %%
user_info = responses['What information do you require data users to supply?']
real_name_required = user_info['Real name'].apply(lambda x: x == 'Real name')
graph_checkbox(user_info[real_name_required])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10ab20cd0>,
#  None                        2.941176
#  Other (please specify)     23.529412
#  Other personal details     32.352941
#  Institution                82.352941
#  Email address              91.176471
#  Real name                 100.000000
#  dtype: float64,
#                                low       high
#  subquestion
#  Email address            8.823529  11.764706
#  Institution             11.764706  14.705882
#  None                     5.882353   2.941176
#  Other (please specify)  14.705882  14.705882
#  Other personal details  14.705882  14.705882
#  Real name                0.000000   0.000000)

# %% [markdown]
# ### How do you currently use the information you collect?

# %%
graph_checkbox(responses['How do you currently use the information you collect?'])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10a407910>,
#  Inform deaccession\ndecisions      6.849315
#  Set levels of service             19.178082
#  Other (please specify)            24.657534
#  Inform collection\ndevelopment    38.356164
#  Set priorities                    46.575342
#  Justify funding                   56.164384
#  dtype: float64,
#                                       low       high
#  subquestion
#  Inform collection development  10.958904  10.958904
#  Inform deaccession decisions    6.849315   5.479452
#  Justify funding                10.958904  10.958904
#  Other (please specify)          9.589041   9.589041
#  Set levels of service           9.589041   8.219178
#  Set priorities                 10.958904  10.958904)

# %% [markdown]
# The most common (56.2%) application for data metrics is as evidence of the value of the repository to funders. However, they are also used by many to inform internal decisions, such as by 46.6% to set priorities and 38.4% to inform collection development.

# %%
INTERNAL_USES = [u'Inform collection development', u'Inform deaccession decisions', 
                 u'Set levels of service', u'Set priorities']

internal_use = responses['How do you currently use the information you collect?'][INTERNAL_USES].any(axis=1).value_counts()
internal_use.apply(lambda x: float(x) / internal_use.sum())
# Out:
# True     0.657534
# False    0.342466
# dtype: float64

# %% [markdown]
# 65.8% of respondents use the information they collect to inform at least one internal decision.

# %% [markdown]
# ## Data Use

# %% [markdown]
# ### How interested you would be to know each of the following about users of the data you hold?

# %%
graph_likert(responses['How interested you would be to know each of the following about <strong>users</strong> of the data you hold?<br><em>Please rank items from most to least interesting.</em>'], 
             INTEREST_LEVELS)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10bb17290>,
#                                                                5 (Least interesting)  \
#  Geographic location                                                       26.415094
#  Clickstreams while\nnavigating your system                                30.909091
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)              15.384615
#  Institutional\naffiliations                                               12.500000
#  Disciplines / research\ncommunities                                        1.923077
#
#                                                                        4  \
#  Geographic location                                           22.641509
#  Clickstreams while\nnavigating your system                    20.000000
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)  32.692308
#  Institutional\naffiliations                                   18.750000
#  Disciplines / research\ncommunities                            5.769231
#
#                                                                        3  \
#  Geographic location                                           28.301887
#  Clickstreams while\nnavigating your system                    12.727273
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)  19.230769
#  Institutional\naffiliations                                   31.250000
#  Disciplines / research\ncommunities                            7.692308
#
#                                                                        2  \
#  Geographic location                                           15.094340
#  Clickstreams while\nnavigating your system                    20.000000
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)  26.923077
#  Institutional\naffiliations                                   27.083333
#  Disciplines / research\ncommunities                           17.307692
#
#                                                                1 (Most interesting)
#  Geographic location                                                       7.547170
#  Clickstreams while\nnavigating your system                               16.363636
#  Institution types (e.g.,\nacademic, commercial,\ngovernment)              5.769231
#  Institutional\naffiliations                                              10.416667
#  Disciplines / research\ncommunities                                      67.307692  )

# %% [markdown]
# There was a clear interest in knowning what disciplines or research communities the repository is serving; 67.3% chose it as the most interesting option. All the others were a roughly similar mix, execpt, perhaps, for clickstreams, which were the first choice of 16.4% of repository managers.

# %% [markdown]
# ### How interested you would be to know each of the following about how the data you hold is used?

# %%
graph_likert(responses['How interested you would be to know each of the following about <strong>how</strong> the data you hold is used?<br><em>Please rank items from most to least interesting.</em>'],
             INTEREST_LEVELS)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x10b99c4d0>,
#                                     5 (Least interesting)          4  \
#  If a subset was used                           29.411765  29.411765
#  If data was misused                            48.148148  11.111111
#  If combined with other\ndata                    5.660377  18.867925
#  If analyses were\nperformed                     8.000000  24.000000
#  If a dataset was derived\nfrom it               4.000000  16.000000
#
#                                             3          2  1 (Most interesting)
#  If a subset was used               31.372549   7.843137              1.960784
#  If data was misused                11.111111  11.111111             18.518519
#  If combined with other\ndata       24.528302  37.735849             13.207547
#  If analyses were\nperformed        10.000000  22.000000             36.000000
#  If a dataset was derived\nfrom it  26.000000  24.000000             30.000000  )

# %% [markdown]
# ### How interested you would be to know each of the following about the impact of the data you hold?

# %%
INTEREST_LEVELS_SEVEN = ['7 (Least interesting)', '6', '5', '4', '3', '2', '1 (Most interesting)']
graph_likert(responses['How interested you would be to know each of the following about the <strong>impact</strong> of the data you hold?<br><em>Please rank items from most to least interesting.</em>'], 
             INTEREST_LEVELS_SEVEN)
plt.savefig('7rows.svg')

# %% [markdown]
# As was the case with rearchers, citations are the most desireable measure of impact as the first choice of 61.1% of respondents. In contrast to this purely scholarly measure, "real-world" impact was the second most desireable, but was the first choice of a much smaller percentage (23.2%) of respondents.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Directly relevant to metrics:
#
# * Citations remain the preferred currency of scholarly prestige. Citation counts are the most valued measure of impact by both reasearchers and repository staff.
#
# * As a measure of impact, download counts are securely in second place in researcher's minds, and many more repositories currently track downloads than citations (85% vs. 23%). In the near term, downloads are an attractive metric in terms of availability.
#
# * Many repositories collect stats that they don't expose.
#
# Researcher data use and discovery behavior:
#
# * Researchers are using other people's data primarily in a supporting role– either before or after their own data collection.
#
# * Researchers look for data in muliple ways; the literature, disciplinary databases, and general purpose search are each used by a majority of researchers.
